# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#To-load-the-data" data-toc-modified-id="To-load-the-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>To load the data</a></span></li><li><span><a href="#Load-the-strong-annotation-and-the-ground-thruth" data-toc-modified-id="Load-the-strong-annotation-and-the-ground-thruth-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load the strong annotation and the ground thruth</a></span></li><li><span><a href="#Optimization" data-toc-modified-id="Optimization-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Optimization</a></span><ul class="toc-item"><li><span><a href="#Threshold" data-toc-modified-id="Threshold-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Threshold</a></span></li><li><span><a href="#Threshold-+-smoothing" data-toc-modified-id="Threshold-+-smoothing-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Threshold + smoothing</a></span></li><li><span><a href="#Hysteris-+-smoothing" data-toc-modified-id="Hysteris-+-smoothing-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Hysteris + smoothing</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Import

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import time
import os
import matplotlib.pyplot as plt
import dcase_util as dcu

from Encoder import Encoder

import numpy as np

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # To load the data

# %%
import numpy as np
import os

class_correspondance = {"Alarm_bell_ringing": 0, "Speech": 1, "Dog": 2, "Cat": 3, "Vacuum_cleaner": 4,
                        "Dishes": 5, "Frying": 6, "Electric_shaver_toothbrush": 7, "Blender": 8, "Running_water": 9}


def load_mil():
    strong_prediction = np.load(os.path.join("..", "data", "mil_strong_prediction.pkl"))
    tmp = dict()

    # Fill the missing curve with zero
    for filename in strong_prediction:
        new_data = np.zeros((431, 10))

        for cls in strong_prediction[filename]:
            new_data[:, class_correspondance[cls]] = strong_prediction[filename][cls]

        tmp[filename] = new_data.copy()

    # Create a list of filename in the same order than the dict
    filename_list = ["%s.wav" % k for k in tmp.keys()]

    # Create a list
    output_data = np.array(list(tmp.values()))

    return output_data, filename_list


def load_baseline():
    filenames = np.load(os.path.join("..", "data", "X_test_fn.npy"))
    strong_prediction = np.load(os.path.join("..", "data", "baseline_strong_prediction.npy"))

    return strong_prediction, filenames


def load_strong_prediction(filename):
    filenames = np.load(os.path.join("..", "data", "X_test_fn.npy"))
    strong_prediction = np.load(os.path.join("data", filename))
    
    return strong_prediction, filenames


def load_ground_truth():
    test_unique_names = np.load(os.path.join("..", "data", "X_test_fn.npy"))

    with open(os.path.join("data", "test.csv"), "r") as f:
        test_metadata = f.read().splitlines()[1:]
    test_metadata = np.array([info.split("\t") for info in test_metadata])
    test_medata_filenames = np.unique(test_metadata[:, 0])

    y_test = []
    for name in test_medata_filenames:
        # remove  missing files
        if name not in test_unique_names:
            continue

        # create a tag level prediction (aka weak labels)
        output = [0] * 10

        for d in test_metadata:
            if d[0] == name:
                output[class_correspondance[d[-1]]] = 1
        y_test.append(output)
    y_test = np.array(y_test)

    return y_test

# %% [markdown]
# # Load the strong annotation and the ground thruth

# %%
# strong_annotation, filenames = Loader.load_mil()
strong_prediction, filenames = load_mil()

# ground truth
with open(os.path.join("..", "data", "test.csv"), "r") as f:
    strong_y_true = f.read().splitlines()[1:]

# %%
strong_prediction.shape
# Out:
# (279, 431, 10)

# %% [markdown]
# # Optimization

# %%
from Encoder import Encoder
import optimizers.DichotomicOptimizer as Optimizer

# %%
class_list = ['Alarm_bell_ringing', 'Speech', 'Dog', 'Cat', 'Vacuum_cleaner', 'Dishes', 'Frying', 'Electric_shaver_toothbrush', 'Blender', 'Running_water']

# Create the encoder that will be used
encoder = Encoder(
    classes=class_list,
    temporal_precision = 200,  # ms
    clip_length = 10,          # s
    minimal_segment_step = 200 # ms
)

# %% [markdown]
# ## Threshold

# %%
t = list(np.random.normal(0.5, 0.1, size=1000))

# %%
# Create the optimizer
optimizer = Optimizer.ThresholdOptimizer(
    {
        "threshold": (0.01, 0.1)
    },
    
    encoder = encoder,
    step = 20,
    nb_recurse = 1,
    nb_process = 12
)

# Perform the optimization
# %time optimizer.fit(y_true, strong_prediction, filenames, verbose=2)
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# CPU times: user 220 ms, sys: 489 ms, total: 709 ms
# Wall time: 6.68 s

# %%
optimizer.results
# Out:
# {(0.1,): {'overall': {'f_measure': {'f_measure': 0.00297059114763838,
#     'precision': 0.0016316762754269552,
#     'recall': 0.016556291390728478},
#    'error_rate': {'error_rate': 10.95916114790287,
#     'substitution_rate': 0.1545253863134658,
#     'deletion_rate': 0.8289183222958058,
#     'insertion_rate': 9.975717439293598},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 4.830357142857142,
#      'deletion_rate': 1.0,
#      'insertion_rate': 3.830357142857143},
#     'count': {'Nref': 112.0, 'Nsys': 429.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 21.85,
#      'deletion_rate': 1.0,
#      'insertion_rate': 20.85},
#     'count': {'Nref': 40.0, 'Nsys': 834.0}},
#    'Cat': {'f_measure': {'f_measure': 0.005221932114882506,
#      'precision': 0.0029239766081871343,
#      'recall': 0.024390243902439025},
#     'accuracy': {},
#     'error_rate': {'error_rate': 9.292682926829269,
#      'deletion_rate': 0.975609756097561,
#      'insertion_rate': 8.317073170731707},
#     'count': {'Nref': 82.0, 'Nsys': 684.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.006958942240779402,
#      'precision': 0.0038022813688212928,
#      'recall': 0.040983606557377046},
#     'accuracy': {},
#     'error_rate': {'error_rate': 11.69672131147541,
#      'deletion_rate': 0.9590163934426229,
#      'insertion_rate': 10.737704918032787},
#     'count': {'Nref': 122.0, 'Nsys': 1315.0}},
#    'Dog': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 8.5,
#      'deletion_rate': 1.0,
#      'insertion_rate': 7.5},
#     'count': {'Nref': 126.0, 'Nsys': 945.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 19.178571428571427,
#      'deletion_rate': 1.0,
#      'insertion_rate': 18.178571428571427},
#     'count': {'Nref': 28.0, 'Nsys': 509.0}},
#    'Frying': {'f_measure': {'f_measure': 0.002171552660152009,
#      'precision': 0.0011148272017837235,
#      'recall': 0.041666666666666664},
#     'accuracy': {},
#     'error_rate': {'error_rate': 38.29166666666667,
#      'deletion_rate': 0.9583333333333334,
#      'insertion_rate': 37.333333333333336},
#     'count': {'Nref': 24.0, 'Nsys': 897.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0025957170668397143,
#      'precision': 0.0013651877133105802,
#      'recall': 0.02631578947368421},
#     'accuracy': {},
#     'error_rate': {'error_rate': 20.223684210526315,
#      'deletion_rate': 0.9736842105263158,
#      'insertion_rate': 19.25},
#     'count': {'Nref': 76.0, 'Nsys': 1465.0}},
#    'Speech': {'f_measure': {'f_measure': 0.00452744765138653,
#      'precision': 0.0026542800265428003,
#      'recall': 0.015384615384615385},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.765384615384615,
#      'deletion_rate': 0.9846153846153847,
#      'insertion_rate': 5.780769230769231},
#     'count': {'Nref': 260.0, 'Nsys': 1507.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.0031055900621118015,
#      'precision': 0.001644736842105263,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 17.833333333333332,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 16.86111111111111},
#     'count': {'Nref': 36.0, 'Nsys': 608.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0024581181796151964,
#     'precision': 0.0013505289760750794,
#     'recall': 0.017651869976256014},
#    'error_rate': {'error_rate': 15.84624016356442,
#     'deletion_rate': 0.982348130023744,
#     'insertion_rate': 14.863892033540674},
#    'accuracy': {}}},
#  (0.2,): {'overall': {'f_measure': {'f_measure': 0.0023892267593397048,
#     'precision': 0.0013249819320645627,
#     'recall': 0.012141280353200883},
#    'error_rate': {'error_rate': 9.992273730684326,
#     'substitution_rate': 0.1467991169977925,
#     'deletion_rate': 0.8410596026490066,
#     'insertion_rate': 9.004415011037528},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 4.464285714285714,
#      'deletion_rate': 1.0,
#      'insertion_rate': 3.4642857142857144},
#     'count': {'Nref': 112.0, 'Nsys': 388.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 19.825,
#      'deletion_rate': 1.0,
#      'insertion_rate': 18.825},
#     'count': {'Nref': 40.0, 'Nsys': 753.0}},
#    'Cat': {'f_measure': {'f_measure': 0.002805049088359046,
#      'precision': 0.001584786053882726,
#      'recall': 0.012195121951219513},
#     'accuracy': {},
#     'error_rate': {'error_rate': 8.670731707317072,
#      'deletion_rate': 0.9878048780487805,
#      'insertion_rate': 7.682926829268292},
#     'count': {'Nref': 82.0, 'Nsys': 631.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.004524886877828054,
#      'precision': 0.0024916943521594683,
#      'recall': 0.02459016393442623},
#     'accuracy': {},
#     'error_rate': {'error_rate': 10.81967213114754,
#      'deletion_rate': 0.9754098360655737,
#      'insertion_rate': 9.844262295081966},
#     'count': {'Nref': 122.0, 'Nsys': 1204.0}},
#    'Dog': {'f_measure': {'f_measure': 0.0022296544035674466,
#      'precision': 0.0012970168612191958,
#      'recall': 0.007936507936507936},
#     'accuracy': {},
#     'error_rate': {'error_rate': 7.103174603174603,
#      'deletion_rate': 0.9920634920634921,
#      'insertion_rate': 6.111111111111111},
#     'count': {'Nref': 126.0, 'Nsys': 771.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 16.142857142857142,
#      'deletion_rate': 1.0,
#      'insertion_rate': 15.142857142857142},
#     'count': {'Nref': 28.0, 'Nsys': 424.0}},
#    'Frying': {'f_measure': {'f_measure': 0.0026109660574412533,
#      'precision': 0.0013477088948787063,
#      'recall': 0.041666666666666664},
#     'accuracy': {},
#     'error_rate': {'error_rate': 31.833333333333332,
#      'deletion_rate': 0.9583333333333334,
#      'insertion_rate': 30.875},
#     'count': {'Nref': 24.0, 'Nsys': 742.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 18.710526315789473,
#      'deletion_rate': 1.0,
#      'insertion_rate': 17.710526315789473},
#     'count': {'Nref': 76.0, 'Nsys': 1346.0}},
#    'Speech': {'f_measure': {'f_measure': 0.004584527220630373,
#      'precision': 0.0026936026936026937,
#      'recall': 0.015384615384615385},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.680769230769231,
#      'deletion_rate': 0.9846153846153847,
#      'insertion_rate': 5.696153846153846},
#     'count': {'Nref': 260.0, 'Nsys': 1485.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.0033670033670033673,
#      'precision': 0.0017921146953405018,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 16.444444444444443,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 15.472222222222221},
#     'count': {'Nref': 36.0, 'Nsys': 558.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.002012208701482954,
#     'precision': 0.001120692355108329,
#     'recall': 0.01295508536512135},
#    'error_rate': {'error_rate': 14.069479462311856,
#     'deletion_rate': 0.9870449146348786,
#     'insertion_rate': 13.082434547676977},
#    'accuracy': {}}},
#  (0.3,): {'overall': {'f_measure': {'f_measure': 0.003480278422273782,
#     'precision': 0.001944516463572725,
#     'recall': 0.016556291390728478},
#    'error_rate': {'error_rate': 9.357615894039736,
#     'substitution_rate': 0.12362030905077263,
#     'deletion_rate': 0.8598233995584988,
#     'insertion_rate': 8.374172185430464},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 4.098214285714286,
#      'deletion_rate': 1.0,
#      'insertion_rate': 3.0982142857142856},
#     'count': {'Nref': 112.0, 'Nsys': 347.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 17.95,
#      'deletion_rate': 1.0,
#      'insertion_rate': 16.95},
#     'count': {'Nref': 40.0, 'Nsys': 678.0}},
#    'Cat': {'f_measure': {'f_measure': 0.0029498525073746312,
#      'precision': 0.0016778523489932886,
#      'recall': 0.012195121951219513},
#     'accuracy': {},
#     'error_rate': {'error_rate': 8.24390243902439,
#      'deletion_rate': 0.9878048780487805,
#      'insertion_rate': 7.2560975609756095},
#     'count': {'Nref': 82.0, 'Nsys': 596.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.006562756357670221,
#      'precision': 0.0036463081130355514,
#      'recall': 0.03278688524590164},
#     'accuracy': {},
#     'error_rate': {'error_rate': 9.926229508196721,
#      'deletion_rate': 0.9672131147540983,
#      'insertion_rate': 8.959016393442623},
#     'count': {'Nref': 122.0, 'Nsys': 1097.0}},
#    'Dog': {'f_measure': {'f_measure': 0.0024752475247524753,
#      'precision': 0.001466275659824047,
#      'recall': 0.007936507936507936},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.396825396825397,
#      'deletion_rate': 0.9920634920634921,
#      'insertion_rate': 5.404761904761905},
#     'count': {'Nref': 126.0, 'Nsys': 682.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 14.821428571428571,
#      'deletion_rate': 1.0,
#      'insertion_rate': 13.821428571428571},
#     'count': {'Nref': 28.0, 'Nsys': 387.0}},
#    'Frying': {'f_measure': {'f_measure': 0.002828854314002829,
#      'precision': 0.0014641288433382138,
#      'recall': 0.041666666666666664},
#     'accuracy': {},
#     'error_rate': {'error_rate': 29.375,
#      'deletion_rate': 0.9583333333333334,
#      'insertion_rate': 28.416666666666668},
#     'count': {'Nref': 24.0, 'Nsys': 683.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 17.5,
#      'deletion_rate': 1.0,
#      'insertion_rate': 16.5},
#     'count': {'Nref': 76.0, 'Nsys': 1254.0}},
#    'Speech': {'f_measure': {'f_measure': 0.008064516129032258,
#      'precision': 0.0047425474254742545,
#      'recall': 0.026923076923076925},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.6230769230769235,
#      'deletion_rate': 0.9730769230769231,
#      'insertion_rate': 5.65},
#     'count': {'Nref': 260.0, 'Nsys': 1476.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.0036363636363636364,
#      'precision': 0.0019455252918287938,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 15.222222222222221,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 14.25},
#     'count': {'Nref': 36.0, 'Nsys': 514.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.002651759046919605,
#     'precision': 0.001494263768249415,
#     'recall': 0.014928603650115047},
#    'error_rate': {'error_rate': 13.015689934648853,
#     'deletion_rate': 0.9850713963498847,
#     'insertion_rate': 12.030618538298967},
#    'accuracy': {}}},
#  (0.4,): {'overall': {'f_measure': {'f_measure': 0.003451676528599605,
#     'precision': 0.0019428254232583958,
#     'recall': 0.01545253863134658},
#    'error_rate': {'error_rate': 8.806843267108167,
#     'substitution_rate': 0.11589403973509933,
#     'deletion_rate': 0.8686534216335541,
#     'insertion_rate': 7.822295805739515},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.8660714285714284,
#      'deletion_rate': 1.0,
#      'insertion_rate': 2.8660714285714284},
#     'count': {'Nref': 112.0, 'Nsys': 321.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 16.325,
#      'deletion_rate': 1.0,
#      'insertion_rate': 15.325},
#     'count': {'Nref': 40.0, 'Nsys': 613.0}},
#    'Cat': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 7.926829268292683,
#      'deletion_rate': 1.0,
#      'insertion_rate': 6.926829268292683},
#     'count': {'Nref': 82.0, 'Nsys': 568.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.007079646017699115,
#      'precision': 0.003968253968253968,
#      'recall': 0.03278688524590164},
#     'accuracy': {},
#     'error_rate': {'error_rate': 9.196721311475411,
#      'deletion_rate': 0.9672131147540983,
#      'insertion_rate': 8.229508196721312},
#     'count': {'Nref': 122.0, 'Nsys': 1008.0}},
#    'Dog': {'f_measure': {'f_measure': 0.002638522427440633,
#      'precision': 0.0015822784810126582,
#      'recall': 0.007936507936507936},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.0,
#      'deletion_rate': 0.9920634920634921,
#      'insertion_rate': 5.007936507936508},
#     'count': {'Nref': 126.0, 'Nsys': 632.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 13.821428571428571,
#      'deletion_rate': 1.0,
#      'insertion_rate': 12.821428571428571},
#     'count': {'Nref': 28.0, 'Nsys': 359.0}},
#    'Frying': {'f_measure': {'f_measure': 0.003139717425431711,
#      'precision': 0.0016313213703099511,
#      'recall': 0.041666666666666664},
#     'accuracy': {},
#     'error_rate': {'error_rate': 26.458333333333332,
#      'deletion_rate': 0.9583333333333334,
#      'insertion_rate': 25.5},
#     'count': {'Nref': 24.0, 'Nsys': 613.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 16.842105263157897,
#      'deletion_rate': 1.0,
#      'insertion_rate': 15.842105263157896},
#     'count': {'Nref': 76.0, 'Nsys': 1204.0}},
#    'Speech': {'f_measure': {'f_measure': 0.00836320191158901,
#      'precision': 0.0049504950495049506,
#      'recall': 0.026923076923076925},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.384615384615385,
#      'deletion_rate': 0.9730769230769231,
#      'insertion_rate': 5.411538461538462},
#     'count': {'Nref': 260.0, 'Nsys': 1414.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.00392156862745098,
#      'precision': 0.002109704641350211,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 14.11111111111111,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 13.13888888888889},
#     'count': {'Nref': 36.0, 'Nsys': 474.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0025142656409611447,
#     'precision': 0.0014242053510431737,
#     'recall': 0.013709091454993095},
#    'error_rate': {'error_rate': 12.093221567198583,
#     'deletion_rate': 0.9862909085450069,
#     'insertion_rate': 11.106930658653575},
#    'accuracy': {}}},
#  (0.5,): {'overall': {'f_measure': {'f_measure': 0.0036406189052138865,
#     'precision': 0.0020633750921149594,
#     'recall': 0.01545253863134658},
#    'error_rate': {'error_rate': 8.354304635761588,
#     'substitution_rate': 0.10375275938189846,
#     'deletion_rate': 0.8807947019867549,
#     'insertion_rate': 7.3697571743929355},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.705357142857143,
#      'deletion_rate': 1.0,
#      'insertion_rate': 2.705357142857143},
#     'count': {'Nref': 112.0, 'Nsys': 303.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 14.6,
#      'deletion_rate': 1.0,
#      'insertion_rate': 13.6},
#     'count': {'Nref': 40.0, 'Nsys': 544.0}},
#    'Cat': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 7.658536585365853,
#      'deletion_rate': 1.0,
#      'insertion_rate': 6.658536585365853},
#     'count': {'Nref': 82.0, 'Nsys': 546.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.007568590350047304,
#      'precision': 0.0042780748663101605,
#      'recall': 0.03278688524590164},
#     'accuracy': {},
#     'error_rate': {'error_rate': 8.598360655737705,
#      'deletion_rate': 0.9672131147540983,
#      'insertion_rate': 7.631147540983607},
#     'count': {'Nref': 122.0, 'Nsys': 935.0}},
#    'Dog': {'f_measure': {'f_measure': 0.005714285714285714,
#      'precision': 0.003484320557491289,
#      'recall': 0.015873015873015872},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.523809523809524,
#      'deletion_rate': 0.9841269841269841,
#      'insertion_rate': 4.5396825396825395},
#     'count': {'Nref': 126.0, 'Nsys': 574.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 13.25,
#      'deletion_rate': 1.0,
#      'insertion_rate': 12.25},
#     'count': {'Nref': 28.0, 'Nsys': 343.0}},
#    'Frying': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 24.208333333333332,
#      'deletion_rate': 1.0,
#      'insertion_rate': 23.208333333333332},
#     'count': {'Nref': 24.0, 'Nsys': 557.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 16.210526315789473,
#      'deletion_rate': 1.0,
#      'insertion_rate': 15.210526315789474},
#     'count': {'Nref': 76.0, 'Nsys': 1156.0}},
#    'Speech': {'f_measure': {'f_measure': 0.00855222968845449,
#      'precision': 0.005083514887436456,
#      'recall': 0.026923076923076925},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.242307692307692,
#      'deletion_rate': 0.9730769230769231,
#      'insertion_rate': 5.269230769230769},
#     'count': {'Nref': 260.0, 'Nsys': 1377.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.00411522633744856,
#      'precision': 0.0022222222222222222,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 13.444444444444443,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 12.472222222222221},
#     'count': {'Nref': 36.0, 'Nsys': 450.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0025950332090236066,
#     'precision': 0.0015068132533460129,
#     'recall': 0.01033607558197722},
#    'error_rate': {'error_rate': 11.344167569364517,
#     'deletion_rate': 0.9896639244180226,
#     'insertion_rate': 10.354503644946496},
#    'accuracy': {}}},
#  (0.6,): {'overall': {'f_measure': {'f_measure': 0.0032697547683923707,
#     'precision': 0.0018650917003419335,
#     'recall': 0.013245033112582781},
#    'error_rate': {'error_rate': 7.975717439293598,
#     'substitution_rate': 0.09933774834437085,
#     'deletion_rate': 0.8874172185430463,
#     'insertion_rate': 6.988962472406181},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.5357142857142856,
#      'deletion_rate': 1.0,
#      'insertion_rate': 2.5357142857142856},
#     'count': {'Nref': 112.0, 'Nsys': 284.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 13.825,
#      'deletion_rate': 1.0,
#      'insertion_rate': 12.825},
#     'count': {'Nref': 40.0, 'Nsys': 513.0}},
#    'Cat': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 7.414634146341464,
#      'deletion_rate': 1.0,
#      'insertion_rate': 6.414634146341464},
#     'count': {'Nref': 82.0, 'Nsys': 526.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.001988071570576541,
#      'precision': 0.0011312217194570137,
#      'recall': 0.00819672131147541},
#     'accuracy': {},
#     'error_rate': {'error_rate': 8.22950819672131,
#      'deletion_rate': 0.9918032786885246,
#      'insertion_rate': 7.237704918032787},
#     'count': {'Nref': 122.0, 'Nsys': 884.0}},
#    'Dog': {'f_measure': {'f_measure': 0.009216589861751152,
#      'precision': 0.005714285714285714,
#      'recall': 0.023809523809523808},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.1190476190476195,
#      'deletion_rate': 0.9761904761904762,
#      'insertion_rate': 4.142857142857143},
#     'count': {'Nref': 126.0, 'Nsys': 525.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 11.892857142857142,
#      'deletion_rate': 1.0,
#      'insertion_rate': 10.892857142857142},
#     'count': {'Nref': 28.0, 'Nsys': 305.0}},
#    'Frying': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 23.208333333333332,
#      'deletion_rate': 1.0,
#      'insertion_rate': 22.208333333333332},
#     'count': {'Nref': 24.0, 'Nsys': 533.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 15.671052631578947,
#      'deletion_rate': 1.0,
#      'insertion_rate': 14.671052631578947},
#     'count': {'Nref': 76.0, 'Nsys': 1115.0}},
#    'Speech': {'f_measure': {'f_measure': 0.008816120906801008,
#      'precision': 0.005271084337349397,
#      'recall': 0.026923076923076925},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.053846153846154,
#      'deletion_rate': 0.9730769230769231,
#      'insertion_rate': 5.0807692307692305},
#     'count': {'Nref': 260.0, 'Nsys': 1328.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.004376367614879651,
#      'precision': 0.0023752969121140144,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 12.638888888888888,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 11.666666666666666},
#     'count': {'Nref': 36.0, 'Nsys': 421.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0024397149954008346,
#     'precision': 0.0014491888683206139,
#     'recall': 0.008670709982185392},
#    'error_rate': {'error_rate': 10.758888239832915,
#     'deletion_rate': 0.9913292900178146,
#     'insertion_rate': 9.7675589498151},
#    'accuracy': {}}},
#  (0.7,): {'overall': {'f_measure': {'f_measure': 0.003492941347693203,
#     'precision': 0.00201173512154233,
#     'recall': 0.013245033112582781},
#    'error_rate': {'error_rate': 7.461368653421634,
#     'substitution_rate': 0.09602649006622517,
#     'deletion_rate': 0.890728476821192,
#     'insertion_rate': 6.474613686534217},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.455357142857143,
#      'deletion_rate': 1.0,
#      'insertion_rate': 2.455357142857143},
#     'count': {'Nref': 112.0, 'Nsys': 275.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 12.225,
#      'deletion_rate': 1.0,
#      'insertion_rate': 11.225},
#     'count': {'Nref': 40.0, 'Nsys': 449.0}},
#    'Cat': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.890243902439025,
#      'deletion_rate': 1.0,
#      'insertion_rate': 5.890243902439025},
#     'count': {'Nref': 82.0, 'Nsys': 483.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.004305705059203445,
#      'precision': 0.0024783147459727386,
#      'recall': 0.01639344262295082},
#     'accuracy': {},
#     'error_rate': {'error_rate': 7.581967213114754,
#      'deletion_rate': 0.9836065573770492,
#      'insertion_rate': 6.598360655737705},
#     'count': {'Nref': 122.0, 'Nsys': 807.0}},
#    'Dog': {'f_measure': {'f_measure': 0.010256410256410256,
#      'precision': 0.006535947712418301,
#      'recall': 0.023809523809523808},
#     'accuracy': {},
#     'error_rate': {'error_rate': 4.595238095238095,
#      'deletion_rate': 0.9761904761904762,
#      'insertion_rate': 3.619047619047619},
#     'count': {'Nref': 126.0, 'Nsys': 459.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 11.0,
#      'deletion_rate': 1.0,
#      'insertion_rate': 10.0},
#     'count': {'Nref': 28.0, 'Nsys': 280.0}},
#    'Frying': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 20.625,
#      'deletion_rate': 1.0,
#      'insertion_rate': 19.625},
#     'count': {'Nref': 24.0, 'Nsys': 471.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 15.105263157894736,
#      'deletion_rate': 1.0,
#      'insertion_rate': 14.105263157894736},
#     'count': {'Nref': 76.0, 'Nsys': 1072.0}},
#    'Speech': {'f_measure': {'f_measure': 0.007792207792207792,
#      'precision': 0.0046875,
#      'recall': 0.023076923076923078},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.876923076923077,
#      'deletion_rate': 0.9769230769230769,
#      'insertion_rate': 4.9},
#     'count': {'Nref': 260.0, 'Nsys': 1280.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.004705882352941175,
#      'precision': 0.002570694087403599,
#      'recall': 0.027777777777777776},
#     'accuracy': {},
#     'error_rate': {'error_rate': 11.75,
#      'deletion_rate': 0.9722222222222222,
#      'insertion_rate': 10.777777777777779},
#     'count': {'Nref': 36.0, 'Nsys': 389.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0027060205460762666,
#     'precision': 0.001627245654579464,
#     'recall': 0.00910576672871755},
#    'error_rate': {'error_rate': 9.910499258846684,
#     'deletion_rate': 0.9908942332712825,
#     'insertion_rate': 8.919605025575402},
#    'accuracy': {}}},
#  (0.8,): {'overall': {'f_measure': {'f_measure': 0.004004312336362236,
#     'precision': 0.0023268301413996778,
#     'recall': 0.01434878587196468},
#    'error_rate': {'error_rate': 7.039735099337748,
#     'substitution_rate': 0.09823399558498896,
#     'deletion_rate': 0.8874172185430463,
#     'insertion_rate': 6.054083885209713},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.3839285714285716,
#      'deletion_rate': 1.0,
#      'insertion_rate': 2.3839285714285716},
#     'count': {'Nref': 112.0, 'Nsys': 267.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 11.05,
#      'deletion_rate': 1.0,
#      'insertion_rate': 10.05},
#     'count': {'Nref': 40.0, 'Nsys': 402.0}},
#    'Cat': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 6.378048780487805,
#      'deletion_rate': 1.0,
#      'insertion_rate': 5.378048780487805},
#     'count': {'Nref': 82.0, 'Nsys': 441.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.004651162790697674,
#      'precision': 0.0027100271002710027,
#      'recall': 0.01639344262295082},
#     'accuracy': {},
#     'error_rate': {'error_rate': 7.016393442622951,
#      'deletion_rate': 0.9836065573770492,
#      'insertion_rate': 6.032786885245901},
#     'count': {'Nref': 122.0, 'Nsys': 738.0}},
#    'Dog': {'f_measure': {'f_measure': 0.014981273408239699,
#      'precision': 0.00980392156862745,
#      'recall': 0.031746031746031744},
#     'accuracy': {},
#     'error_rate': {'error_rate': 4.174603174603175,
#      'deletion_rate': 0.9682539682539683,
#      'insertion_rate': 3.2063492063492065},
#     'count': {'Nref': 126.0, 'Nsys': 408.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 10.25,
#      'deletion_rate': 1.0,
#      'insertion_rate': 9.25},
#     'count': {'Nref': 28.0, 'Nsys': 259.0}},
#    'Frying': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 19.458333333333332,
#      'deletion_rate': 1.0,
#      'insertion_rate': 18.458333333333332},
#     'count': {'Nref': 24.0, 'Nsys': 443.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 14.513157894736842,
#      'deletion_rate': 1.0,
#      'insertion_rate': 13.513157894736842},
#     'count': {'Nref': 76.0, 'Nsys': 1027.0}},
#    'Speech': {'f_measure': {'f_measure': 0.00941492938802959,
#      'precision': 0.0057049714751426246,
#      'recall': 0.026923076923076925},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.665384615384616,
#      'deletion_rate': 0.9730769230769231,
#      'insertion_rate': 4.6923076923076925},
#     'count': {'Nref': 260.0, 'Nsys': 1227.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 11.416666666666666,
#      'deletion_rate': 1.0,
#      'insertion_rate': 10.416666666666666},
#     'count': {'Nref': 36.0, 'Nsys': 375.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0029047365586966963,
#     'precision': 0.0018218920144041078,
#     'recall': 0.00750625512920595},
#    'error_rate': {'error_rate': 9.330651647926397,
#     'deletion_rate': 0.992493744870794,
#     'insertion_rate': 8.338157903055603},
#    'accuracy': {}}},
#  (0.9,): {'overall': {'f_measure': {'f_measure': 0.005138746145940391,
#     'precision': 0.0030413625304136255,
#     'recall': 0.016556291390728478},
#    'error_rate': {'error_rate': 6.3156732891832235,
#     'substitution_rate': 0.09492273730684327,
#     'deletion_rate': 0.8885209713024282,
#     'insertion_rate': 5.3322295805739515},
#    'accuracy': {}},
#   'class_wise': {'Alarm_bell_ringing': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.25,
#      'deletion_rate': 1.0,
#      'insertion_rate': 2.25},
#     'count': {'Nref': 112.0, 'Nsys': 252.0}},
#    'Blender': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 9.125,
#      'deletion_rate': 1.0,
#      'insertion_rate': 8.125},
#     'count': {'Nref': 40.0, 'Nsys': 325.0}},
#    'Cat': {'f_measure': {'f_measure': 0.004514672686230248,
#      'precision': 0.002770083102493075,
#      'recall': 0.012195121951219513},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.378048780487806,
#      'deletion_rate': 0.9878048780487805,
#      'insertion_rate': 4.390243902439025},
#     'count': {'Nref': 82.0, 'Nsys': 361.0}},
#    'Dishes': {'f_measure': {'f_measure': 0.005689900426742532,
#      'precision': 0.0034423407917383822,
#      'recall': 0.01639344262295082},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.729508196721311,
#      'deletion_rate': 0.9836065573770492,
#      'insertion_rate': 4.745901639344262},
#     'count': {'Nref': 122.0, 'Nsys': 581.0}},
#    'Dog': {'f_measure': {'f_measure': 0.011834319526627219,
#      'precision': 0.007874015748031496,
#      'recall': 0.023809523809523808},
#     'accuracy': {},
#     'error_rate': {'error_rate': 3.9761904761904763,
#      'deletion_rate': 0.9761904761904762,
#      'insertion_rate': 3.0},
#     'count': {'Nref': 126.0, 'Nsys': 381.0}},
#    'Electric_shaver_toothbrush': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 8.464285714285715,
#      'deletion_rate': 1.0,
#      'insertion_rate': 7.464285714285714},
#     'count': {'Nref': 28.0, 'Nsys': 209.0}},
#    'Frying': {'f_measure': {'f_measure': 0.0, 'precision': 0.0, 'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 17.291666666666668,
#      'deletion_rate': 1.0,
#      'insertion_rate': 16.291666666666668},
#     'count': {'Nref': 24.0, 'Nsys': 391.0}},
#    'Running_water': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 13.776315789473685,
#      'deletion_rate': 1.0,
#      'insertion_rate': 12.776315789473685},
#     'count': {'Nref': 76.0, 'Nsys': 971.0}},
#    'Speech': {'f_measure': {'f_measure': 0.013215859030837003,
#      'precision': 0.008166969147005444,
#      'recall': 0.03461538461538462},
#     'accuracy': {},
#     'error_rate': {'error_rate': 5.1692307692307695,
#      'deletion_rate': 0.9653846153846154,
#      'insertion_rate': 4.203846153846154},
#     'count': {'Nref': 260.0, 'Nsys': 1102.0}},
#    'Vacuum_cleaner': {'f_measure': {'f_measure': 0.0,
#      'precision': 0.0,
#      'recall': 0.0},
#     'accuracy': {},
#     'error_rate': {'error_rate': 10.972222222222221,
#      'deletion_rate': 1.0,
#      'insertion_rate': 9.972222222222221},
#     'count': {'Nref': 36.0, 'Nsys': 359.0}}},
#   'class_wise_average': {'f_measure': {'f_measure': 0.0035254751670436998,
#     'precision': 0.0022253408789268394,
#     'recall': 0.008701347299907876},
#    'error_rate': {'error_rate': 8.313246861527864,
#     'deletion_rate': 0.9912986527000921,
#     'insertion_rate': 7.321948208827772},
#    'accuracy': {}}}}

# %%
# monitor one metrics
def monitor_one(results, metric):
    out = []
    
    for k in results.keys():
        out.append((k, results[k]["overall"]["f_measure"][metric]))
        
    out = sorted(out, key=lambda x: x[0])
    
    return np.array(out)

def display_history(metric):
    x, y = metric[:, 0], metric[:, 1]

    max_y = max(y)
    max_x = list(y).index(max_y)

    plt.figure(figsize=(20, 5))
    plt.subplot(1, 2, 1)
    plt.title("f_measure")
    plt.plot(y, label="f1")
    plt.plot(max_x, max_y, "ro", label="f1:%.2f th:%.4f" % (max_y, x[max_x][0]))

    plt.ylabel("f1")
    plt.xlabel("threshold")
#     plt.xticks(range(len(x)), x, rotation=80)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.hist(list(y))
    plt.show()
    
    return x[list(y).index(max_y)]

# %%
f1 = monitor_one(optimizer.results, "f_measure")
best_combination = display_history(f1)

# %% [markdown]
# ## Threshold + smoothing

# %%
## Threshold smoothing and smoothing window size
# Create the optimizer
optimizer = Optimizer.ThresholdOptimizer(
    {
        "threshold": (0.01, 0.1),
        "smooth": "smoothMovingAvg",
        "window_len": [3, 7, 11, 13, 15, 17, 19, 21]
    },
    
    encoder = encoder,
    step = 12,
    nb_recurse = 3,
    nb_process = 20
)

# Perform the optimization
# %time optimizer.fit(y_true, strong_prediction, filenames, verbose=2)
# Out:
# HBox(children=(IntProgress(value=0, max=288), HTML(value='')))
# CPU times: user 2.49 s, sys: 6.11 s, total: 8.6 s
# Wall time: 1min 16s

# %%
f1 = monitor_one(optimizer.results, "f_measure")
best_combination = display_history(f1)
print(best_combination)
# Out:
# (0.026363636363636367, 'smoothMovingAvg', 17)

# %% [markdown]
# ## Hysteris + smoothing

# %%
## Threshold smoothing and smoothing window size
# Create the optimizer
optimizer = Optimizer.ThresholdOptimizer(
    {
        "low": (0.01, 0.9),
    "high": [0.1, 0.2, 0.4,
        "smooth": "smoothMovingAvg",
        "window_len": (3, 29)
    },
    
    encoder = encoder,
    step = 12,
    nb_recurse = 3,
    nb_process = 20
)

# Perform the optimization
# %time optimizer.fit(y_true, strong_prediction, filenames, method="hysteresis", verbose=2)
# Out:
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# CPU times: user 45.7 s, sys: 1min 51s, total: 2min 37s
# Wall time: 17min 30s

# %%
f1 = monitor_one(optimizer.results, "f_measure")
best_combination = display_history(f1)
print(best_combination)
# Out:
# (0.01, 0.09090909090909091, 'smoothMovingAvg', 17.181818181818183)
